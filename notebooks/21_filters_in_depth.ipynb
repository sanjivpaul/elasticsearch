# %% [markdown]
# To read more about filters, checkout the docs [here](https://www.elastic.co/docs/reference/elasticsearch/rest-apis/filter-search-results)

# %% [markdown]
# ## Connect to ElasticSearch

# %%
from pprint import pprint
from elasticsearch import Elasticsearch

es = Elasticsearch('http://localhost:9200')
client_info = es.info()
print('Connected to Elasticsearch!')
pprint(client_info.body)
# Out:
# Connected to Elasticsearch!
# {'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'FQt-ffZfTpeh0Snf3pUAQw',
#  'name': 'ae8b5b4be42b',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2024-08-05T10:05:34.233336849Z',
#              'build_flavor': 'default',
#              'build_hash': '1a77947f34deddb41af25e6f0ddb8e830159c179',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '9.11.1',
#              'minimum_index_compatibility_version': '7.0.0',
#              'minimum_wire_compatibility_version': '7.17.0',
#              'number': '8.15.0'}}

# %% [markdown]
# ## Index data

# %%
import json
from pprint import pprint

es.indices.delete(index='my_index', ignore_unavailable=True)
es.indices.create(index='my_index')

operations = []
clothes_documents = json.load(open("../data/clothes.json"))


for document in clothes_documents:
    operations.append({'index':{'_index':'my_index'}})
    operations.append(document)

response = es.bulk(operations=operations)
pprint(response.body)
# Out:
# {'errors': False,
#  'items': [{'index': {'_id': 'VrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 0,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'V7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 1,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'WLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 2,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'WbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 3,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'WrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 4,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'W7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 5,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'XLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 6,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'XbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 7,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'XrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 8,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'X7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 9,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'YLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 10,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'YbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 11,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'YrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 12,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'Y7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 13,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ZLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 14,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ZbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 15,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ZrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 16,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'Z7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 17,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'aLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 18,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'abJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 19,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'arJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 20,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'a7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 21,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'bLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 22,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'bbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 23,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'brJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 24,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'b7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 25,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'cLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 26,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'cbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 27,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'crJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 28,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'c7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 29,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'dLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 30,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'dbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 31,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'drJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 32,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'd7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 33,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'eLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 34,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ebJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 35,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'erJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 36,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'e7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 37,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'fLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 38,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'fbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 39,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'frJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 40,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'f7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 41,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'gLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 42,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'gbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 43,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'grJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 44,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'g7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 45,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'hLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 46,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'hbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 47,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'hrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 48,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'h7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 49,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'iLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 50,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ibJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 51,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'irJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 52,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'i7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 53,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'jLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 54,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'jbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 55,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'jrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 56,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'j7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 57,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'kLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 58,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'kbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 59,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'krJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 60,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'k7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 61,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'lLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 62,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'lbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 63,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'lrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 64,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'l7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 65,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'mLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 66,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'mbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 67,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'mrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 68,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'm7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 69,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'nLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 70,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'nbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 71,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'nrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 72,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'n7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 73,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'oLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 74,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'obJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 75,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'orJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 76,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'o7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 77,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'pLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 78,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'pbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 79,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'prJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 80,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'p7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 81,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'qLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 82,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'qbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 83,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'qrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 84,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'q7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 85,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'rLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 86,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'rbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 87,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'rrJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 88,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'r7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 89,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'sLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 90,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'sbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 91,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'srJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 92,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 's7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 93,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'tLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 94,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'tbJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 95,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'trJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 96,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 't7JWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 97,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'uLJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 98,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ubJWTZoBesPIpDe2ntLK',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 99,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}}],
#  'took': 29052244}

# %%
count = es.count(index='my_index')
print(f"Number of documents in index: {count.body['count']}")
# Out:
# Number of documents in index: 0

# %% [markdown]
# ## Simple Filters

# %% [markdown]
# Previously, we learned about compound queries. Using a boolean query, you can apply filters to narrow down documents based on specific criteria. In this simple example, we filter documents to keep only those where the brand is Adidas.

# %%
response = es.search(
    index="my_index",
    body={
        "query":{
            "bool":{
                "filter": [
                    {
                        "term":{
                            "brand":"adidas",
                        }
                    }
                ]
            }
        },
        "size":100
    }
)

hits = response.body['hits']['hits']
print(f"Found {len(hits)} documents")
# Out:
# Found 23 documents

# %% [markdown]
# Here, we apply multiple filters using an AND operation to retain documents where the brand is Adidas and the color is yellow.

# %%
response = es.search(
    index="my_index",
    body={
        "query":{
            "bool": {
                "filter": [
                    {
                         "term": {
                             "color": "yellow",
                         },

                    },
                    {
                        "term": {
                            "brand": "adidas",
                        }
                    }
                ]
            }
        }
    }
)

hits = response.body['hits']['hits']
print(f"Found {len(hits)} documents")
# Out:
# Found 6 documents

# %% [markdown]
# ## Post Filters

# %% [markdown]
# In this example, we'll explore the use of filters, aggregations, filtered aggregations, and post-filters.
#
#
# We start by narrowing our search to documents where the `brand` is `gucci`. Next, we apply aggregations to determine the document count for each color. We then define a filtered aggregation, `color_red`, which counts the models in documents where the color is `red`.
#
# Finally, a `post_filter` is used after performing the aggregations, refining the search results to include only documents with the color `red`.

# %%
response = es.search(
    index="my_index",
    body={
        "query":{
            "bool": {
                "filter": {
                    "term": {
                        "brand": "gucci"
                    }
                }
            }
        },
        "aggs": {
            "colors": {
                "terms": {
                    "field": "color.keyword"
                }
            },
            "color_red": {
                "filter": {
                    "term": {
                        "color.keyword": "red",
                    }
                },
                "aggs": {
                    "models": {
                        "terms": {
                            "field": "model.keyword",

                        }
                    }
                }
            }
        },
        "post_filter": {
            "term": {
                "color": "red"
            }
        },
        "size":20
    }
)

pprint(response.body)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'color_red': {'doc_count': 12,
#                                 'models': {'buckets': [{'doc_count': 3,
#                                                         'key': 'model_1'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_14'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_16'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_2'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_26'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_28'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_3'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_4'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_6'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_8'}],
#                                            'doc_count_error_upper_bound': 0,
#                                            'sum_other_doc_count': 0}},
#                   'colors': {'buckets': [{'doc_count': 12, 'key': 'red'},
#                                          {'doc_count': 8, 'key': 'blue'},
#                                          {'doc_count': 6, 'key': 'green'},
#                                          {'doc_count': 4, 'key': 'yellow'}],
#                              'doc_count_error_upper_bound': 0,
#                              'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': 'VrJWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'WLJWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_3'}},
#                    {'_id': 'WrJWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'X7JWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_4'}},
#                    {'_id': 'YrJWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'a7JWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_2'}},
#                    {'_id': 'e7JWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_28'}},
#                    {'_id': 'g7JWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_6'}},
#                    {'_id': 'i7JWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_14'}},
#                    {'_id': 'l7JWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_26'}},
#                    {'_id': 'o7JWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_8'}},
#                    {'_id': 'q7JWTZoBesPIpDe2ntLK',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_16'}}],
#           'max_score': 0.0,
#           'total': {'relation': 'eq', 'value': 12}},
#  'timed_out': False,
#  'took': 57}

# %% [markdown]
# The `colors_aggregation` variable holds the count of documents associated with each color, as returned by the aggregation query.

# %%
colors_aggregation = response.body['aggregations']['colors']['buckets']
pprint(colors_aggregation)
# Out:
# [{'doc_count': 12, 'key': 'red'},
#  {'doc_count': 8, 'key': 'blue'},
#  {'doc_count': 6, 'key': 'green'},
#  {'doc_count': 4, 'key': 'yellow'}]

# %% [markdown]
# The `color_red_aggregation` variable contains the results from the `color_red` filtered aggregation, which includes the count of models specifically for documents where the color is `red`.

# %%
color_red_aggregation = response.body['aggregations']['color_red']['models']['buckets']
pprint(color_red_aggregation)
# Out:
# [{'doc_count': 3, 'key': 'model_1'},
#  {'doc_count': 1, 'key': 'model_14'},
#  {'doc_count': 1, 'key': 'model_16'},
#  {'doc_count': 1, 'key': 'model_2'},
#  {'doc_count': 1, 'key': 'model_26'},
#  {'doc_count': 1, 'key': 'model_28'},
#  {'doc_count': 1, 'key': 'model_3'},
#  {'doc_count': 1, 'key': 'model_4'},
#  {'doc_count': 1, 'key': 'model_6'},
#  {'doc_count': 1, 'key': 'model_8'}]

# %% [markdown]
# To get the search results after the post-filter has been applied, we access the `hits` from `response.body['hits']['hits']`. This allows us to iterate through each result and display details such as the shirt's brand, color, and model.

# %%
hits = response.body['hits']['hits']
for hit in hits:
    print(f"""Shirt brand: {hit['_source']['brand']}, color: {hit['_source']['color']}, and model: {hit['_source']['model']}""")
# Out:
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_3
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_4
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_2
# Shirt brand: gucci, color: red, and model: model_28
# Shirt brand: gucci, color: red, and model: model_6
# Shirt brand: gucci, color: red, and model: model_14
# Shirt brand: gucci, color: red, and model: model_26
# Shirt brand: gucci, color: red, and model: model_8
# Shirt brand: gucci, color: red, and model: model_16
