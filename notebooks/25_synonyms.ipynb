# %% [markdown]
# To read more about synonyms, checkout the docs [here](https://www.elastic.co/docs/api/doc/elasticsearch/group/endpoint-synonyms).

# %% [markdown]
# ## Connect To ElasticSearch

# %%
from pprint import pprint
from elasticsearch import Elasticsearch

es = Elasticsearch('http://localhost:9200')
client_info = es.info()
print('Connected to Elasticsearch!')
pprint(client_info.body)
# Out:
# Connected to Elasticsearch!
# {'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'FQt-ffZfTpeh0Snf3pUAQw',
#  'name': 'ae8b5b4be42b',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2024-08-05T10:05:34.233336849Z',
#              'build_flavor': 'default',
#              'build_hash': '1a77947f34deddb41af25e6f0ddb8e830159c179',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '9.11.1',
#              'minimum_index_compatibility_version': '7.0.0',
#              'minimum_wire_compatibility_version': '7.17.0',
#              'number': '8.15.0'}}

# %% [markdown]
# ## Setting up Synonyms

# %% [markdown]
# We are creating an index with a custom analyzer that uses a synonym filter to expand terms like "car" to include "automobile" and "vehicle."

# %%
from pprint import pprint

settings={
    "settings": {
        "analysis": {
            "filter": {
                "synonym_filter": {
                    "type": "synonym",
                    "synonyms": [
                        "car, automobile, vehicle",
                        "tv telivision",
                        "smartphone, mobile, cell phone",
                        "jupyter, jupyter notebook, jupyterlab",
                        "jupiter, mars, earth, venus, mercury, saturn, uranus, neptune => planet"
                    ]
                }
            },
            "analyzer": {
                "synonym_analyzer": {
                    "tokenizer": "standard",
                    "filter": [
                        "lowercase",
                        "synonym_filter",
                    ]
                }
            }
        },

    },
    "mappings":{
        "properties":{
            "description": {
                "type": "text",
                "analyzer": "synonym_analyzer",
            }
        }
    }
}

index_name = "my_synonym_index"
es.indices.delete(index=index_name, ignore_unavailable=True)
response = es.indices.create(index=index_name, body=settings)
pprint(response.body)
# Out:
# {'acknowledged': True, 'index': 'my_synonym_index', 'shards_acknowledged': True}

# %% [markdown]
# ## Indexing documents

# %%
import json
from tqdm import tqdm

operations= []
dummy_data = json.load(open("../data/synonyms.json"))

for document in tqdm(dummy_data, total=len(dummy_data)):
    operations.append({'index':{ '_index': index_name}})
    operations.append(document)

response = es.bulk(operations=operations)
pprint(response.body)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 13058.23it/s]
# {'errors': False,
#  'items': [{'index': {'_id': 'O87iXJoBBloM_uUc-o0N',
#                       '_index': 'my_synonym_index',
#                       '_primary_term': 1,
#                       '_seq_no': 0,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'PM7iXJoBBloM_uUc-o0N',
#                       '_index': 'my_synonym_index',
#                       '_primary_term': 1,
#                       '_seq_no': 1,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'Pc7iXJoBBloM_uUc-o0O',
#                       '_index': 'my_synonym_index',
#                       '_primary_term': 1,
#                       '_seq_no': 2,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'Ps7iXJoBBloM_uUc-o0O',
#                       '_index': 'my_synonym_index',
#                       '_primary_term': 1,
#                       '_seq_no': 3,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'P87iXJoBBloM_uUc-o0O',
#                       '_index': 'my_synonym_index',
#                       '_primary_term': 1,
#                       '_seq_no': 4,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}}],
#  'took': 1058971}

# %% [markdown]
# ## Searching with Synonyms

# %% [markdown]
# Now, let’s search for terms that should match synonyms. For example, we’ll search for "vehicle" (which should match "car" or "automobile").

# %%
query={
    "query":{
        "match": {
            "description": "vehicle"
        }
    }
}

response = es.search(
    index=index_name,
    body=query
)

print("Search Result: ")
for hit in response["hits"]["hits"]:
    print(hit["_source"])
# Out:
# Search Result:
# {'description': 'I love my car and television.'}

# %%
query={
    "query":{
        "match": {
            "description": "planet"
        }
    }
}

response = es.search(
    index=index_name,
    body=query
)

print("Search Result: ")
for hit in response["hits"]["hits"]:
    print(hit["_source"])
# Out:
# Search Result:
# {'description': 'I want to go to Mars.'}
# {'description': 'I want to go to Venus.'}

# %% [markdown]
# ## Expanding Synonyms for Search-Time Only

# %% [markdown]
# If you want to apply synonyms only during search (and not while indexing), you can modify the search query analyzer like this.

# %%
settings={
    "settings": {
        "analysis": {
            "filter" : {
                "synonym_filter": {
                    "type": "synonym",
                    "synonyms": [
                        "car, automobile, vehicle",
                        "tv, television"
                    ]
                }
            },
            "analyzer": {
                "index_analyzer": {
                    "tokenizer": "standard",
                    "filter": ["lowercase"]
                },
                "search_analyzer": {
                    "tokenizer": "standard",
                    "filter": ["lowercase", "synonym_filter"]
                }
            }
        }
    },
    "mappings": {
        "properties": {
            "description": {
                "type": "text",
                "analyzer": "index_analyzer",
                "search_analyzer": "search_analyzer"
            }
        }
    }
}

es.indices.delete(index=index_name)
response = es.indices.create(index=index_name, body=settings)
pprint(response.body)
# Out:
# {'acknowledged': True, 'index': 'my_synonym_index', 'shards_acknowledged': True}

# %%
import json
from tqdm import tqdm

operations= []
dummy_data = json.load(open("../data/synonyms.json"))

for document in tqdm(dummy_data, total=len(dummy_data)):
    operations.append({'index':{ '_index': index_name}})
    operations.append(document)

response = es.bulk(operations=operations)
pprint(response.body)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 72315.59it/s]
# {'errors': False,
#  'items': [{'index': {'_id': 'Qc71XJoBBloM_uUciI0j',
#                       '_index': 'my_synonym_index',
#                       '_primary_term': 1,
#                       '_seq_no': 0,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'Qs71XJoBBloM_uUciI0k',
#                       '_index': 'my_synonym_index',
#                       '_primary_term': 1,
#                       '_seq_no': 1,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'Q871XJoBBloM_uUciI0k',
#                       '_index': 'my_synonym_index',
#                       '_primary_term': 1,
#                       '_seq_no': 2,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'RM71XJoBBloM_uUciI0k',
#                       '_index': 'my_synonym_index',
#                       '_primary_term': 1,
#                       '_seq_no': 3,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'Rc71XJoBBloM_uUciI0k',
#                       '_index': 'my_synonym_index',
#                       '_primary_term': 1,
#                       '_seq_no': 4,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}}],
#  'took': 2274962}

# %%
query = {
    "query": {
        "match": {
            "description": "vehicle"
        }
    }
}

response = es.search(index=index_name, body=query)

print("Search Results (Search-time synonyms):")
for hit in response["hits"]["hits"]:
    print(hit["_source"])
# Out:
# Search Results (Search-time synonyms):
# {'description': 'I love my car and television.'}
